# %% [markdown]
# # Data Wrangling Project

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
# import warnings

# %%
df1=pd.read_csv("dataset_1 - dataset_1.csv")
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df2=pd.read_csv("dataset_2.xlsx - dataset_2.csv")
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df3=pd.read_csv('dataset_3 - dataset_3.csv')
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
df1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
df1.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
df2.isnull()
# Out:
#      Unnamed: 0  instant  atemp    hum  windspeed  casual  registered    cnt
# 0         False    False  False  False      False   False       False  False
# 1         False    False  False  False      False   False       False  False
# 2         False    False  False  False      False   False       False  False
# 3         False    False  False  False      False   False       False  False
# 4         False    False  False  False      False   False       False  False
# ..          ...      ...    ...    ...        ...     ...         ...    ...
# 605       False    False  False  False      False   False       False  False
# 606       False    False  False  False      False   False       False  False
# 607       False    False  False  False      False   False       False  False
# 608       False    False  False  False      False   False       False  False
# 609       False    False  False  False      False   False       False  False
#
# [610 rows x 8 columns]

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df2.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
df2.describe()
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
sns.countplot(x='temp',data=df3)
# Out:
# <Axes: xlabel='temp', ylabel='count'>

# %%
sns.countplot(x='weathersit',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
print(df1)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
plt.figure(figsize=(6,4))  # to know the outliers of particular column
sns.boxplot(df1['weathersit'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df1['temp'])
plt.show()

# %%
print(df2)
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.describe()
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %%
plt.figure(figsize=(6,4))  # to know outliers of the particular column
sns.boxplot(df2['atemp'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df2['hum'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df2['windspeed'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df2['casual'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df2['registered'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df2['cnt'])
plt.show()

# %%
print(df3)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
df3.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df1.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df2.head(5)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df2=df2.drop(['Unnamed: 0'],axis=1)
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
# merge of dataset one and two
# on for taking common columns
# how 
df1_2=pd.merge(df1,df2,on='instant',how='inner')

# %%
df1_2.shape
# Out:
# (610, 16)

# %%
df1_2
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df1_2.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df1_2.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df1_2['atemp'].value_counts()
# Out:
# atemp
# 0.1970    69
# 0.2273    64
# 0.2121    55
# 0.1818    47
# 0.1515    45
# 0.1212    41
# 0.1364    39
# 0.2576    36
# 0.1667    25
# 0.2727    23
# 0.2424    20
# 0.1061    17
# 0.2879    16
# 0.0758    15
# 0.3333    12
# 0.0606    10
# 0.3030    10
# 0.4091     8
# 0.3182     8
# 0.0909     7
# 0.0303     7
# 0.4242     6
# 0.3485     5
# 0.4545     4
# 0.4394     2
# 0.3939     2
# 0.0455     2
# 0.0000     2
# 0.0152     2
# Name: count, dtype: int64

# %%
df1_2['atemp'].unique()
# Out:
# array([0.2879, 0.2727, 0.2576,    nan, 0.3485, 0.3939, 0.3333, 0.4242,
#        0.4545, 0.4394, 0.4091, 0.2273, 0.2121, 0.197 , 0.1364, 0.1061,
#        0.1212, 0.1667, 0.1818, 0.2424, 0.1515, 0.3182, 0.0606, 0.0758,
#        0.0909, 0.303 , 0.0303, 0.0455, 0.    , 0.0152])

# %%
df1_2.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean     0.196885    0.199935    0.562475    0.204851    4.501639   51.068852
# ...

# %%
df3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
df2.head(15)
# Out:
#     instant   atemp   hum  windspeed  casual  registered  cnt
# 0         1  0.2879  0.81     0.0000       3          13   16
# 1         2  0.2727  0.80     0.0000       8          32   40
# 2         3  0.2727  0.80     0.0000       5          27   32
# 3         4  0.2879  0.75     0.0000       3          10   13
# 4         5  0.2879  0.75     0.0000       0           1    1
# 5         6  0.2576  0.75     0.0896       0           1    1
# 6         7  0.2727  0.80     0.0000       2           0    2
# 7         8  0.2576  0.86     0.0000       1           2    3
# 8         9     NaN  0.75     0.0000       1           7    8
# 9        10  0.3485  0.76     0.0000       8           6   14
# 10       11  0.3939  0.76     0.2537      12          24   36
# 11       12  0.3333  0.81     0.2836      26          30   56
# 12       13  0.4242  0.77     0.2836      29          55   84
# 13       14  0.4545  0.72     0.2985      47          47   94
# ...

# %%
df2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df2.dropna(inplace=True)
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 7 columns]

# %%
df2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 7 columns]

# %%
df1_2=pd.merge(df1,df2,on='instant')
df1_2
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 594      606  28-01-2011       1   0     1  11    False        5           3
# 595      607  28-01-2011       1   0     1  12    False        5           3
# 596      608  28-01-2011       1   0     1  13    False        5           3
# 597      609  28-01-2011       1   0     1  14    False        5           3
# 598      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df1_2.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  599.000000   599.0  599.0  599.0  599.000000  599.000000  599.000000
# mean   310.377295     1.0    0.0    1.0   11.796327    2.993322    1.475793
# std    174.076400     0.0    0.0    0.0    6.837966    2.043005    0.643203
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    161.500000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    311.000000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    460.500000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp       atemp         hum   windspeed      casual  registered  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     0.194758    0.199935    0.560935    0.204502    4.494157   51.532554
# ...

# %%
df1_2['windspeed'].unique()
# Out:
# array([0.    , 0.0896, 0.2537, 0.2836, 0.2985, 0.194 , 0.2239, 0.1343,
#        0.1642, 0.3284, 0.4478, 0.3582, 0.3881, 0.1045, 0.4925, 0.5522,
#        0.4627, 0.4179, 0.5224, 0.5821])

# %%
df1_2['casual'].unique()
# Out:
# array([ 3,  8,  5,  0,  2,  1, 12, 26, 29, 47, 35, 40, 41,  9,  6, 11,  4,
#         7, 16, 20, 19, 10, 13, 14, 18, 17, 15, 21, 33, 23, 22, 24],
#       dtype=int64)

# %%
df1_2.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df1_2.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df1_2_3=pd.concat([df1,df2,df3])
df1_2_3
# Out:
#      instant      dteday  season   yr  mnth    hr holiday  weekday  \
# 0          1  01-01-2011     1.0  0.0   1.0   0.0   False      6.0
# 1          2  01-01-2011     1.0  0.0   1.0   1.0   False      6.0
# 2          3  01-01-2011     1.0  0.0   1.0   2.0   False      6.0
# 3          4  01-01-2011     1.0  0.0   1.0   3.0   False      6.0
# 4          5  01-01-2011     1.0  0.0   1.0   4.0   False      6.0
# ..       ...         ...     ...  ...   ...   ...     ...      ...
# 385      615  28-01-2011     1.0  0.0   1.0  20.0   False      5.0
# 386      616  28-01-2011     1.0  0.0   1.0  21.0   False      5.0
# 387      617  28-01-2011     1.0  0.0   1.0  22.0   False      5.0
# 388      618  28-01-2011     1.0  0.0   1.0  23.0   False      5.0
# 389      619  29-01-2011     1.0  0.0   1.0   0.0   False      6.0
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered   cnt
# 0           1.0  0.24     NaN   NaN        NaN     NaN         NaN   NaN
# ...

# %%
df1_2_3.dtypes
# Out:
# instant         int64
# dteday         object
# season        float64
# yr            float64
# mnth          float64
# hr            float64
# holiday        object
# weekday       float64
# weathersit    float64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual        float64
# registered    float64
# cnt           float64
# dtype: object

# %%
df1_2_3.describe()
# Out:
#            instant  season      yr         mnth           hr      weekday  \
# count  1599.000000  1000.0  1000.0  1000.000000  1000.000000  1000.000000
# mean    429.278299     1.0     0.0     1.312000    11.753000     2.982000
# std     268.257091     0.0     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     206.000000     1.0     0.0     1.000000     6.000000     1.000000
# 50%     406.000000     1.0     0.0     1.000000    12.000000     3.000000
# 75%     605.500000     1.0     0.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         weathersit         temp       atemp         hum   windspeed  \
# count  1000.000000  1000.000000  989.000000  989.000000  989.000000
# mean      1.480000     0.205900    0.211958    0.581769    0.194609
# std       0.651171     0.078977    0.076703    0.187706    0.129225
# ...

# %%
df1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1599 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1599 non-null   int64
#  1   dteday      1000 non-null   object
#  2   season      1000 non-null   float64
#  3   yr          1000 non-null   float64
#  4   mnth        1000 non-null   float64
#  5   hr          1000 non-null   float64
#  6   holiday     1000 non-null   object
#  7   weekday     1000 non-null   float64
#  8   weathersit  1000 non-null   float64
#  9   temp        1000 non-null   float64
#  10  atemp       989 non-null    float64
#  11  hum         989 non-null    float64
#  12  windspeed   989 non-null    float64
#  13  casual      989 non-null    float64
#  14  registered  989 non-null    float64
#  15  cnt         989 non-null    float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 212.4+ KB

# %%
df1_2_3.isnull()
# Out:
#      instant  dteday  season     yr   mnth     hr  holiday  weekday  \
# 0      False   False   False  False  False  False    False    False
# 1      False   False   False  False  False  False    False    False
# 2      False   False   False  False  False  False    False    False
# 3      False   False   False  False  False  False    False    False
# 4      False   False   False  False  False  False    False    False
# ..       ...     ...     ...    ...    ...    ...      ...      ...
# 385    False   False   False  False  False  False    False    False
# 386    False   False   False  False  False  False    False    False
# 387    False   False   False  False  False  False    False    False
# 388    False   False   False  False  False  False    False    False
# 389    False   False   False  False  False  False    False    False
#
#      weathersit   temp  atemp    hum  windspeed  casual  registered    cnt
# 0         False  False   True   True       True    True        True   True
# ...

# %%
df1_2_3.isnull().sum()
# Out:
# instant         0
# dteday        599
# season        599
# yr            599
# mnth          599
# hr            599
# holiday       599
# weekday       599
# weathersit    599
# temp          599
# atemp         610
# hum           610
# windspeed     610
# casual        610
# registered    610
# cnt           610
# dtype: int64

# %%
new_data = df1_2_3.dropna(axis = 0, how ='any')
new_data
# Out:
#      instant      dteday  season   yr  mnth    hr holiday  weekday  \
# 0        620  29-01-2011     1.0  0.0   1.0   1.0   False      6.0
# 1        621  29-01-2011     1.0  0.0   1.0   2.0   False      6.0
# 2        622  29-01-2011     1.0  0.0   1.0   3.0   False      6.0
# 3        623  29-01-2011     1.0  0.0   1.0   4.0   False      6.0
# 4        624  29-01-2011     1.0  0.0   1.0   6.0   False      6.0
# ..       ...         ...     ...  ...   ...   ...     ...      ...
# 385      615  28-01-2011     1.0  0.0   1.0  20.0   False      5.0
# 386      616  28-01-2011     1.0  0.0   1.0  21.0   False      5.0
# 387      617  28-01-2011     1.0  0.0   1.0  22.0   False      5.0
# 388      618  28-01-2011     1.0  0.0   1.0  23.0   False      5.0
# 389      619  29-01-2011     1.0  0.0   1.0   0.0   False      6.0
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered   cnt
# 0           1.0  0.22  0.2273  0.64     0.1940     0.0        20.0  20.0
# ...

# %%
df1_2
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 594      606  28-01-2011       1   0     1  11    False        5           3
# 595      607  28-01-2011       1   0     1  12    False        5           3
# 596      608  28-01-2011       1   0     1  13    False        5           3
# 597      609  28-01-2011       1   0     1  14    False        5           3
# 598      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df1_2.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  599.000000   599.0  599.0  599.0  599.000000  599.000000  599.000000
# mean   310.377295     1.0    0.0    1.0   11.796327    2.993322    1.475793
# std    174.076400     0.0    0.0    0.0    6.837966    2.043005    0.643203
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    161.500000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    311.000000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    460.500000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp       atemp         hum   windspeed      casual  registered  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     0.194758    0.199935    0.560935    0.204502    4.494157   51.532554
# ...

# %%
df1_2_3.describe()
# Out:
#            instant  season      yr         mnth           hr      weekday  \
# count  1599.000000  1000.0  1000.0  1000.000000  1000.000000  1000.000000
# mean    429.278299     1.0     0.0     1.312000    11.753000     2.982000
# std     268.257091     0.0     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     206.000000     1.0     0.0     1.000000     6.000000     1.000000
# 50%     406.000000     1.0     0.0     1.000000    12.000000     3.000000
# 75%     605.500000     1.0     0.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         weathersit         temp       atemp         hum   windspeed  \
# count  1000.000000  1000.000000  989.000000  989.000000  989.000000
# mean      1.480000     0.205900    0.211958    0.581769    0.194609
# std       0.651171     0.078977    0.076703    0.187706    0.129225
# ...

# %%
df3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
# Upto this what we have done till now , wrangling part of the data is done and we can bring out the insights of the data
